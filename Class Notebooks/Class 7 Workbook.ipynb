# %%
import pandas as pd
import numpy as np
import scikit

# %%
df = pd.read_csv('/Users/ethanalter/Dropbox (Personal)/GA-4K-DataScience/git-class-do_not_modify/dat-11-15/Homework/Unit2/data/housing.csv')

# %% [markdown]
# Copy file paths by right-clicking and holding down the option key to reveal the menu option

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# ...

# %% [markdown]
# ## First Machine Learning Discussion

# %%
#scikit learn is less "flat" than pandas and numpy
#we'll typically import from sub-modules, as below

from sklearn.tree import DecisionTreeRegressor

# %%
#intialize algorithm
#sklearn is very object-oriented
tree = DecisionTreeRegressor(max_depth = 3)

# %%
#define inputs and outputs - typical for scikit learn 
X = df.iloc[:,:-1] #grab all rows and every column except the last one 
Y = df['PRICE']

# %%
#DO THE THING - do the pattern-matching
tree.fit(X,Y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
#but wait, I want to see it 
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
#we don't love matplotlib, but sklearn built it's stuff on top

# %%
#initialize figure 
plt.figure(figsize = (16,10))
plot_tree(tree, filled=True, fontsize = 13, feature_names = X.columns);

# %% [markdown]
# Decision trees are the base ingredient for gradient-boosting. They are also the building blocks for tree-based
